# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_countries = pd.read_csv("countries_revenue.csv")

# %%
df_countries['total_revenue'].head()
# Out:
# 0     850.96
# 1     559.70
# 2    3685.31
# Name: total_revenue, dtype: float64

# %%
usa = df_countries['country'] == 'United States'
canada = df_countries['country'] == 'Canada'
uk = df_countries['country'] == 'United Kingdom'
labels = [usa, canada, uk]
cu = df_countries['total_revenue']
df = pd.DataFrame(labels)
#def func(res):
for i in df: 
    res = lambda x : "uk" if i==0 else "can" if i==1 else "us" 
    print(res(i))
du = df_countries['country']#, df_countries.iloc[1], df_countries.iloc[2] 
print(du)
plt.pie(x=cu, labels=cu)
plt.title('Total revenue for US, Canada, And UK')
plt.legend(du, title = 'Countries Total')
plt.show()
# Out:
# uk
# can
# us
# 0    United Kingdom
# 1            Canada
# 2     United States
# Name: country, dtype: object
